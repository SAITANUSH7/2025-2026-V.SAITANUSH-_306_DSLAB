# %% [markdown]
# <a href="https://colab.research.google.com/github/SAITANUSH7/2025-2026-V.SAITANUSH-_306_DSLAB/blob/main/WEEK-5/Standardizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#STANDARIZATION

import numpy as np
import math
x = np.array([10,12,44,45,50,55,70])
N = len(x)
print("Population:", x)
mu = np.sum(x)/N
print("Population mean (mu):", mu)
a2 = np.sum((x - mu)**2)
sigma2 = a2/N
sigma = math.sqrt(sigma2)
print("Population standard deviation (sigma):", sigma)
sample = np.array([20,30,40])
n = len(sample)
print("Sample:", sample)
x_bar = np.sum(sample)/n
print("Sample mean (x_bar):", x_bar)
Z = (x_bar - mu) / (sigma / math.sqrt(n))
print("Z score:", Z)
# Out:
# Population: [10 12 44 45 50 55 70]
# Population mean (mu): 40.857142857142854
# Population standard deviation (sigma): 20.51082342450006
# Sample: [20 30 40]
# Sample mean (x_bar): 30.0
# Z score: -0.9168390105266244
